# %% [markdown]
# This is a practice notebook for simple Matplotlib and Pandas.  <br> there are a lot of other libraries and packages you can use for plotting your training. For this exercise we'll focus on Matplotlib

# %% [markdown]
# ### Import Libraries you'll need

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ### Plot a line plot

# %% [markdown]
# ### Plot multiline plot

# %% [markdown]
# ### Plot a Scatterplot

# %% [markdown]
# ### Plot bar chart

# %% [markdown]
# ### Plot a Sub-plot
